# %%
# %pip install catboost scikit-learn pandas numpy
# Out:
# Requirement already satisfied: catboost in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (1.2.8)
# Requirement already satisfied: scikit-learn in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (2.4.0)
# Requirement already satisfied: graphviz in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from catboost) (3.10.8)
# Requirement already satisfied: scipy in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from catboost) (6.5.1)
# Requirement already satisfied: six in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from matplotlib->catboost) (3.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/aravind/Desktop/Projects/NeuralNetNexus2025/.venv/lib/python3.11/site-packages (from plotly->catboost) (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
sample_submission = pd.read_csv("../data/sample_submission.csv")

# %%
TARGET = "Revenue"

X = train.drop(columns=[TARGET])
y = train[TARGET].astype(int)

# %%
CAT_COLS = ["Month", "VisitorType", "Weekend"]

# %%
def preprocess(df):
    df = df.copy()

    for col in CAT_COLS:
        if col in df.columns:

            df[col] = df[col].astype(str)
            df[col] = df[col].replace(['nan', 'None', 'null'], 'MISSING')
            df[col] = df[col].fillna("MISSING")

            df[col] = df[col].replace('0.0', '0')
            df[col] = df[col].replace('1.0', '1')

    num_cols = df.columns.difference(CAT_COLS)
    for col in num_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    return df

X = preprocess(X)
test = preprocess(test)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
model = CatBoostClassifier(
    iterations=500,
    depth=8,
    learning_rate=0.05,
    loss_function="Logloss",
    eval_metric="Precision",     
    l2_leaf_reg=10,
    random_seed=42,
    early_stopping_rounds=100,
    verbose=100
)

# %%
model.fit(
    X_train,
    y_train,
    eval_set=(X_val, y_val),
    cat_features=CAT_COLS,
    use_best_model=True
)
# Out:
# 0:	learn: 0.6694915	test: 0.6613546	best: 0.6613546 (0)	total: 24.2ms	remaining: 12.1s
# 100:	learn: 0.8286334	test: 0.8080808	best: 0.8247423 (54)	total: 1.11s	remaining: 4.4s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.824742268
# bestIteration = 54
#
# Shrink model to first 55 iterations.

# %%
val_pred = model.predict(X_val)

print("Validation Accuracy :", accuracy_score(y_val, val_pred))
print("Validation Precision:", precision_score(y_val, val_pred))
# Out:
# Validation Accuracy : 0.9078947368421053
# Validation Precision: 0.8247422680412371

# %%
test_pool = Pool(
    data=test,
    cat_features=CAT_COLS
)

test_pred = model.predict(test_pool)

submission = sample_submission.copy()
submission[TARGET] = test_pred.astype(bool)
submission.to_csv("answer.csv", index=False)

# %%
import joblib

joblib.dump(model, "AravindAshokan.joblib")
# Out:
# ['AravindAshokan.joblib']
